# %%
import os
import json
import getpass
from dotenv import load_dotenv

from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import DirectoryLoader, JSONLoader

# %%
def load_bus_json_with_metadata(path: str):
    documents = []

    with open(path, "r") as f:
        data = json.load(f)

    # ➤ Load districts and dropping points
    for district in data["districts"]:
        district_name = district["name"]

        for drop in district["dropping_points"]:
            doc_text = (
                f"District: {district_name}\n"
                f"Dropping Point: {drop['name']}\n"
                f"Price: {drop['price']}"
            )

            metadata = {
                "type": "dropping_point",
                "district": district_name,
                "dropping_point": drop["name"],
                "price": drop["price"]
            }

            documents.append(Document(page_content=doc_text, metadata=metadata))

    for provider in data["bus_providers"]:
        provider_name = provider["name"]
        coverage = provider["coverage_districts"]

        doc_text = (
            f"Bus Provider: {provider_name}\n"
            f"Coverage Districts: {', '.join(coverage)}"
        )

        metadata = {
            "type": "bus provider",
            "provider_name": provider_name,
            "coverage_districts": ", ".join(coverage)
        }

        documents.append(Document(page_content=doc_text, metadata=metadata))

    return documents

# %%
loader1 = DirectoryLoader("../data/attachment", glob="*.txt")
loader2 = load_bus_json_with_metadata("../data/data.json")
loader1

# %%
text_document = loader1.load()
text_document.extend(loader2)
text_document
# Out:
# [Document(metadata={'source': '..\\data\\attachment\\desh travel.txt'}, page_content='Desh Travel Privacy Policy\n\nDesh Travel is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: 70A Progoti Shoroni, Lift 4, Rupayan Millennium Square, Dhaka 1212, Bangladesh Contact Information: Email: info@deshtravelbd.com Privacy Policy / Terms Link: https://www.deshtravelbd.com/termsandcondition?utm_source=chatgpt.com\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.\n\nBy utilizing Desh Travel services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'source': '..\\data\\attachment\\ena.txt'}, page_content='Ena Privacy Policy\n\nEna is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: StarNet, Plot 97/A, 2nd Floor, Road-7, Sector-4, Uttara C/A, Dhaka-1230 Contact Information: Mohakhali Bus Stand: 01760-737650 (Non-AC) & 01619-737650 (AC) Privacy Policy / Terms Link: See website for full Privacy Policy\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.\n\nBy utilizing Ena services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'source': '..\\data\\attachment\\green line.txt'}, page_content='Green Line Privacy Policy\n\nGreen Line is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: 9/2, Outer Circular Road, Momen Bagh, Rajarbagh, Dhaka 1217 Contact Information: Tel: +88 02 8315380, Call Center Mobile: 09613316557 Privacy Policy / Terms Link: Refer to website for Privacy Policy\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.\n\nBy utilizing Green Line services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'source': '..\\data\\attachment\\hanif.txt'}, page_content='Hanif Privacy Policy\n\nHanif is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: Gabtoli / Mirpur region, Dhaka Contact Information: Customer Support: 16460, Counter: 01713-049540 Privacy Policy / Terms Link: https://hanifenterprisebd.com/privacy-policy?utm_source=chatgpt.com\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.\n\nBy utilizing Hanif services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'source': '..\\data\\attachment\\shyamoli.txt'}, page_content='Shyamoli Privacy Policy\n\nShyamoli is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: 27/ka, Pisciculture Housing Society, Shyamoli, Mohammadpur, Dhaka-1207 Contact Information: Reservations/Complaints: 01908899544, 01908899522, 01908899499 Privacy Policy / Terms Link: Full Privacy Policy available on website\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.\n\nBy utilizing Shyamoli services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'source': '..\\data\\attachment\\soudia.txt'}, page_content='Soudia Privacy Policy\n\nSoudia is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: Panthapath, Dhaka 1205 Contact Information: Dhaka Panthapath Counter: 01919-654926 Privacy Policy / Terms Link: See website or counter for Privacy Policy\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.\n\nBy utilizing Soudia services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Dhaka', 'dropping_point': 'Gabtoli', 'price': 500}, page_content='District: Dhaka\nDropping Point: Gabtoli\nPrice: 500'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Dhaka', 'dropping_point': 'Mohakhali', 'price': 550}, page_content='District: Dhaka\nDropping Point: Mohakhali\nPrice: 550'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Dhaka', 'dropping_point': 'Sayedabad', 'price': 520}, page_content='District: Dhaka\nDropping Point: Sayedabad\nPrice: 520'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Chattogram', 'dropping_point': 'Muradpur', 'price': 600}, page_content='District: Chattogram\nDropping Point: Muradpur\nPrice: 600'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Chattogram', 'dropping_point': 'Agrabad', 'price': 650}, page_content='District: Chattogram\nDropping Point: Agrabad\nPrice: 650'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Chattogram', 'dropping_point': 'Kaptai', 'price': 620}, page_content='District: Chattogram\nDropping Point: Kaptai\nPrice: 620'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Khulna', 'dropping_point': 'Daulatpur', 'price': 400}, page_content='District: Khulna\nDropping Point: Daulatpur\nPrice: 400'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Khulna', 'dropping_point': 'Khalishpur', 'price': 420}, page_content='District: Khulna\nDropping Point: Khalishpur\nPrice: 420'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Rajshahi', 'dropping_point': 'Shah Makhdum', 'price': 480}, page_content='District: Rajshahi\nDropping Point: Shah Makhdum\nPrice: 480'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Rajshahi', 'dropping_point': 'Bagha', 'price': 500}, page_content='District: Rajshahi\nDropping Point: Bagha\nPrice: 500'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Sylhet', 'dropping_point': 'Zindabazar', 'price': 700}, page_content='District: Sylhet\nDropping Point: Zindabazar\nPrice: 700'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Sylhet', 'dropping_point': 'Bimanbandar', 'price': 720}, page_content='District: Sylhet\nDropping Point: Bimanbandar\nPrice: 720'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Barishal', 'dropping_point': 'Khanjahan', 'price': 450}, page_content='District: Barishal\nDropping Point: Khanjahan\nPrice: 450'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Barishal', 'dropping_point': 'Bakerganj', 'price': 470}, page_content='District: Barishal\nDropping Point: Bakerganj\nPrice: 470'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Rangpur', 'dropping_point': 'Kachari', 'price': 480}, page_content='District: Rangpur\nDropping Point: Kachari\nPrice: 480'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Rangpur', 'dropping_point': 'Cantonment', 'price': 500}, page_content='District: Rangpur\nDropping Point: Cantonment\nPrice: 500'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Mymensingh', 'dropping_point': 'Shahbazpur', 'price': 460}, page_content='District: Mymensingh\nDropping Point: Shahbazpur\nPrice: 460'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Mymensingh', 'dropping_point': 'Kewatkhali', 'price': 480}, page_content='District: Mymensingh\nDropping Point: Kewatkhali\nPrice: 480'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Comilla', 'dropping_point': 'Kotbari', 'price': 530}, page_content='District: Comilla\nDropping Point: Kotbari\nPrice: 530'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Comilla', 'dropping_point': 'Nangalkot', 'price': 550}, page_content='District: Comilla\nDropping Point: Nangalkot\nPrice: 550'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Bogra', 'dropping_point': 'Shahjahanpur', 'price': 470}, page_content='District: Bogra\nDropping Point: Shahjahanpur\nPrice: 470'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Bogra', 'dropping_point': 'Sariakandi', 'price': 490}, page_content='District: Bogra\nDropping Point: Sariakandi\nPrice: 490'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Desh Travel', 'coverage_districts': 'Dhaka, Chattogram, Sylhet, Rangpur'}, page_content='Bus Provider: Desh Travel\nCoverage Districts: Dhaka, Chattogram, Sylhet, Rangpur'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Hanif', 'coverage_districts': 'Dhaka, Khulna, Mymensingh, Comilla'}, page_content='Bus Provider: Hanif\nCoverage Districts: Dhaka, Khulna, Mymensingh, Comilla'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Ena', 'coverage_districts': 'Chattogram, Sylhet, Barishal, Bogra'}, page_content='Bus Provider: Ena\nCoverage Districts: Chattogram, Sylhet, Barishal, Bogra'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Green Line', 'coverage_districts': 'Khulna, Rajshahi, Mymensingh, Rangpur'}, page_content='Bus Provider: Green Line\nCoverage Districts: Khulna, Rajshahi, Mymensingh, Rangpur'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Soudia', 'coverage_districts': 'Dhaka, Rajshahi, Barishal, Comilla'}, page_content='Bus Provider: Soudia\nCoverage Districts: Dhaka, Rajshahi, Barishal, Comilla'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Shyamoli', 'coverage_districts': 'Chattogram, Khulna, Sylhet, Bogra'}, page_content='Bus Provider: Shyamoli\nCoverage Districts: Chattogram, Khulna, Sylhet, Bogra')]

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200, add_start_index=True )

documents = text_splitter.split_documents(text_document)
documents
# Out:
# [Document(metadata={'source': '..\\data\\attachment\\desh travel.txt', 'start_index': 0}, page_content='Desh Travel Privacy Policy\n\nDesh Travel is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: 70A Progoti Shoroni, Lift 4, Rupayan Millennium Square, Dhaka 1212, Bangladesh Contact Information: Email: info@deshtravelbd.com Privacy Policy / Terms Link: https://www.deshtravelbd.com/termsandcondition?utm_source=chatgpt.com\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.'),
#  Document(metadata={'source': '..\\data\\attachment\\desh travel.txt', 'start_index': 906}, page_content='By utilizing Desh Travel services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'source': '..\\data\\attachment\\ena.txt', 'start_index': 0}, page_content='Ena Privacy Policy\n\nEna is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: StarNet, Plot 97/A, 2nd Floor, Road-7, Sector-4, Uttara C/A, Dhaka-1230 Contact Information: Mohakhali Bus Stand: 01760-737650 (Non-AC) & 01619-737650 (AC) Privacy Policy / Terms Link: See website for full Privacy Policy\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.'),
#  Document(metadata={'source': '..\\data\\attachment\\ena.txt', 'start_index': 883}, page_content='By utilizing Ena services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'source': '..\\data\\attachment\\green line.txt', 'start_index': 0}, page_content='Green Line Privacy Policy\n\nGreen Line is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: 9/2, Outer Circular Road, Momen Bagh, Rajarbagh, Dhaka 1217 Contact Information: Tel: +88 02 8315380, Call Center Mobile: 09613316557 Privacy Policy / Terms Link: Refer to website for Privacy Policy\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.'),
#  Document(metadata={'source': '..\\data\\attachment\\green line.txt', 'start_index': 875}, page_content='By utilizing Green Line services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'source': '..\\data\\attachment\\hanif.txt', 'start_index': 0}, page_content='Hanif Privacy Policy\n\nHanif is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: Gabtoli / Mirpur region, Dhaka Contact Information: Customer Support: 16460, Counter: 01713-049540 Privacy Policy / Terms Link: https://hanifenterprisebd.com/privacy-policy?utm_source=chatgpt.com\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.'),
#  Document(metadata={'source': '..\\data\\attachment\\hanif.txt', 'start_index': 862}, page_content='By utilizing Hanif services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'source': '..\\data\\attachment\\shyamoli.txt', 'start_index': 0}, page_content='Shyamoli Privacy Policy\n\nShyamoli is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: 27/ka, Pisciculture Housing Society, Shyamoli, Mohammadpur, Dhaka-1207 Contact Information: Reservations/Complaints: 01908899544, 01908899522, 01908899499 Privacy Policy / Terms Link: Full Privacy Policy available on website\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.'),
#  Document(metadata={'source': '..\\data\\attachment\\shyamoli.txt', 'start_index': 897}, page_content='By utilizing Shyamoli services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'source': '..\\data\\attachment\\soudia.txt', 'start_index': 0}, page_content='Soudia Privacy Policy\n\nSoudia is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: Panthapath, Dhaka 1205 Contact Information: Dhaka Panthapath Counter: 01919-654926 Privacy Policy / Terms Link: See website or counter for Privacy Policy\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.'),
#  Document(metadata={'source': '..\\data\\attachment\\soudia.txt', 'start_index': 822}, page_content='By utilizing Soudia services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Dhaka', 'dropping_point': 'Gabtoli', 'price': 500, 'start_index': 0}, page_content='District: Dhaka\nDropping Point: Gabtoli\nPrice: 500'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Dhaka', 'dropping_point': 'Mohakhali', 'price': 550, 'start_index': 0}, page_content='District: Dhaka\nDropping Point: Mohakhali\nPrice: 550'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Dhaka', 'dropping_point': 'Sayedabad', 'price': 520, 'start_index': 0}, page_content='District: Dhaka\nDropping Point: Sayedabad\nPrice: 520'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Chattogram', 'dropping_point': 'Muradpur', 'price': 600, 'start_index': 0}, page_content='District: Chattogram\nDropping Point: Muradpur\nPrice: 600'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Chattogram', 'dropping_point': 'Agrabad', 'price': 650, 'start_index': 0}, page_content='District: Chattogram\nDropping Point: Agrabad\nPrice: 650'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Chattogram', 'dropping_point': 'Kaptai', 'price': 620, 'start_index': 0}, page_content='District: Chattogram\nDropping Point: Kaptai\nPrice: 620'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Khulna', 'dropping_point': 'Daulatpur', 'price': 400, 'start_index': 0}, page_content='District: Khulna\nDropping Point: Daulatpur\nPrice: 400'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Khulna', 'dropping_point': 'Khalishpur', 'price': 420, 'start_index': 0}, page_content='District: Khulna\nDropping Point: Khalishpur\nPrice: 420'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Rajshahi', 'dropping_point': 'Shah Makhdum', 'price': 480, 'start_index': 0}, page_content='District: Rajshahi\nDropping Point: Shah Makhdum\nPrice: 480'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Rajshahi', 'dropping_point': 'Bagha', 'price': 500, 'start_index': 0}, page_content='District: Rajshahi\nDropping Point: Bagha\nPrice: 500'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Sylhet', 'dropping_point': 'Zindabazar', 'price': 700, 'start_index': 0}, page_content='District: Sylhet\nDropping Point: Zindabazar\nPrice: 700'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Sylhet', 'dropping_point': 'Bimanbandar', 'price': 720, 'start_index': 0}, page_content='District: Sylhet\nDropping Point: Bimanbandar\nPrice: 720'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Barishal', 'dropping_point': 'Khanjahan', 'price': 450, 'start_index': 0}, page_content='District: Barishal\nDropping Point: Khanjahan\nPrice: 450'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Barishal', 'dropping_point': 'Bakerganj', 'price': 470, 'start_index': 0}, page_content='District: Barishal\nDropping Point: Bakerganj\nPrice: 470'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Rangpur', 'dropping_point': 'Kachari', 'price': 480, 'start_index': 0}, page_content='District: Rangpur\nDropping Point: Kachari\nPrice: 480'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Rangpur', 'dropping_point': 'Cantonment', 'price': 500, 'start_index': 0}, page_content='District: Rangpur\nDropping Point: Cantonment\nPrice: 500'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Mymensingh', 'dropping_point': 'Shahbazpur', 'price': 460, 'start_index': 0}, page_content='District: Mymensingh\nDropping Point: Shahbazpur\nPrice: 460'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Mymensingh', 'dropping_point': 'Kewatkhali', 'price': 480, 'start_index': 0}, page_content='District: Mymensingh\nDropping Point: Kewatkhali\nPrice: 480'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Comilla', 'dropping_point': 'Kotbari', 'price': 530, 'start_index': 0}, page_content='District: Comilla\nDropping Point: Kotbari\nPrice: 530'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Comilla', 'dropping_point': 'Nangalkot', 'price': 550, 'start_index': 0}, page_content='District: Comilla\nDropping Point: Nangalkot\nPrice: 550'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Bogra', 'dropping_point': 'Shahjahanpur', 'price': 470, 'start_index': 0}, page_content='District: Bogra\nDropping Point: Shahjahanpur\nPrice: 470'),
#  Document(metadata={'type': 'dropping_point', 'district': 'Bogra', 'dropping_point': 'Sariakandi', 'price': 490, 'start_index': 0}, page_content='District: Bogra\nDropping Point: Sariakandi\nPrice: 490'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Desh Travel', 'coverage_districts': 'Dhaka, Chattogram, Sylhet, Rangpur', 'start_index': 0}, page_content='Bus Provider: Desh Travel\nCoverage Districts: Dhaka, Chattogram, Sylhet, Rangpur'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Hanif', 'coverage_districts': 'Dhaka, Khulna, Mymensingh, Comilla', 'start_index': 0}, page_content='Bus Provider: Hanif\nCoverage Districts: Dhaka, Khulna, Mymensingh, Comilla'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Ena', 'coverage_districts': 'Chattogram, Sylhet, Barishal, Bogra', 'start_index': 0}, page_content='Bus Provider: Ena\nCoverage Districts: Chattogram, Sylhet, Barishal, Bogra'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Green Line', 'coverage_districts': 'Khulna, Rajshahi, Mymensingh, Rangpur', 'start_index': 0}, page_content='Bus Provider: Green Line\nCoverage Districts: Khulna, Rajshahi, Mymensingh, Rangpur'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Soudia', 'coverage_districts': 'Dhaka, Rajshahi, Barishal, Comilla', 'start_index': 0}, page_content='Bus Provider: Soudia\nCoverage Districts: Dhaka, Rajshahi, Barishal, Comilla'),
#  Document(metadata={'type': 'bus provider', 'provider_name': 'Shyamoli', 'coverage_districts': 'Chattogram, Khulna, Sylhet, Bogra', 'start_index': 0}, page_content='Bus Provider: Shyamoli\nCoverage Districts: Chattogram, Khulna, Sylhet, Bogra')]

# %%
load_dotenv()

if not os.getenv("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key: ")

# if not os.getenv("OPENAI_API_KEY"):
#     os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

vector_store = Chroma(
    collection_name="bus_infomation",
    embedding_function=embeddings,
    persist_directory="../data/bus_db"
)

# %%
for i in documents[20:]:
    print(i.metadata)
# Out:
# {'type': 'dropping_point', 'district': 'Rajshahi', 'dropping_point': 'Shah Makhdum', 'price': 480, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Rajshahi', 'dropping_point': 'Bagha', 'price': 500, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Sylhet', 'dropping_point': 'Zindabazar', 'price': 700, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Sylhet', 'dropping_point': 'Bimanbandar', 'price': 720, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Barishal', 'dropping_point': 'Khanjahan', 'price': 450, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Barishal', 'dropping_point': 'Bakerganj', 'price': 470, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Rangpur', 'dropping_point': 'Kachari', 'price': 480, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Rangpur', 'dropping_point': 'Cantonment', 'price': 500, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Mymensingh', 'dropping_point': 'Shahbazpur', 'price': 460, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Mymensingh', 'dropping_point': 'Kewatkhali', 'price': 480, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Comilla', 'dropping_point': 'Kotbari', 'price': 530, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Comilla', 'dropping_point': 'Nangalkot', 'price': 550, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Bogra', 'dropping_point': 'Shahjahanpur', 'price': 470, 'start_index': 0}
# {'type': 'dropping_point', 'district': 'Bogra', 'dropping_point': 'Sariakandi', 'price': 490, 'start_index': 0}
# {'type': 'bus provider', 'provider_name': 'Desh Travel', 'coverage_districts': 'Dhaka, Chattogram, Sylhet, Rangpur', 'start_index': 0}
# {'type': 'bus provider', 'provider_name': 'Hanif', 'coverage_districts': 'Dhaka, Khulna, Mymensingh, Comilla', 'start_index': 0}
# {'type': 'bus provider', 'provider_name': 'Ena', 'coverage_districts': 'Chattogram, Sylhet, Barishal, Bogra', 'start_index': 0}
# {'type': 'bus provider', 'provider_name': 'Green Line', 'coverage_districts': 'Khulna, Rajshahi, Mymensingh, Rangpur', 'start_index': 0}
# {'type': 'bus provider', 'provider_name': 'Soudia', 'coverage_districts': 'Dhaka, Rajshahi, Barishal, Comilla', 'start_index': 0}
# {'type': 'bus provider', 'provider_name': 'Shyamoli', 'coverage_districts': 'Chattogram, Khulna, Sylhet, Bogra', 'start_index': 0}

# %%
document_ids = vector_store.add_documents(documents=documents)
# Out:
# ['b8695309-cb39-4cb1-bfed-7cf2b67307db',
#  '136733f5-0675-422e-b58a-9038884d4109',
#  'a64304a1-0a27-4433-9792-05da00897b79',
#  'fab519d0-3610-41ec-a9f5-c5a8da7f3100',
#  'e1fdcdb0-2eba-41a6-a422-42bebd600a86',
#  'aab3df78-c3e8-418f-9429-f42a05528d55',
#  '89630da8-20c1-49e3-b7e0-3d88f59dc52c',
#  '3dc2a198-edef-426a-86a1-135cef98b9c4',
#  '21fa1e5e-e7b2-4387-95e8-74c0204698df',
#  '7c2888d1-31f7-4b5b-bb8b-556f54e95ab4',
#  'c1da947a-db66-4c09-ace9-615d7679b1e2',
#  'c8c82f48-6391-4526-b8ef-a8a3b1c0a71b',
#  '7a52fe6e-5771-4e23-b837-f7a09990739f',
#  '128c32ff-03a4-4d27-8a41-74ec95773ad2',
#  'c5344f75-55bb-450e-966d-7465ab38fb7d',
#  '1107ca6f-4e7e-48b2-b6cd-5f1ce3018ffc',
#  '6c3cfd95-e7bf-4c15-a0eb-38e2ae458f12',
#  '9be9aa7d-30e2-4317-b112-4578668ec543',
#  '8cc95011-5d91-4bc9-b02a-a7199f00c32d',
#  '958797b0-5625-42e3-8828-5d686da91781',
#  '6f4893d6-2ccd-4440-98ce-624e8de4b118',
#  '726d01ba-caf1-43f9-967e-c0dc378382e4',
#  '5734599a-9aa5-4858-a32e-ec1f327924ee',
#  '56800c80-ab16-4fa0-94ca-72ba00470e22',
#  '663571c1-bbab-4d7d-ad32-3d236c9e11de',
#  '018e8139-ca34-43ec-ae02-68d209bf6b74',
#  'd59583fd-45ef-4a35-9c1e-73a13bc99c7e',
#  '8b6b7997-068b-4c97-bb1f-5ffac807a5af',
#  '2021d7a0-24e6-48c1-9cc5-abfead0c5431',
#  '463b6c07-ff0e-4ffc-bec1-a6a13cfc0e79',
#  '63fe568e-1cba-42fc-9f51-ec5f67044933',
#  '75932ac0-6d3a-4d4e-883b-bf8ef1a72568',
#  '75d23864-6615-4bfe-9d20-53ec5cc44a04',
#  '62c06213-bb86-4d41-9a9a-2bcf74490710',
#  'fedd04ce-5622-4237-9800-93b3b5e24129',
#  '1f2533bf-0852-4c32-982b-cb30a743c6d0',
#  '1648700b-077e-462b-9d27-9dcc06300083',
#  'bae4b3f8-fda8-4c2a-b6f5-d2268fb03a99',
#  '77f32ce5-90b7-4ca2-8aac-8ee71e8a3653',
#  '17166f97-8df4-41b8-bd32-fe001f4ef504']

# %%
query = "“What are the contact details of Hanif Bus?” "
retireved_results=vector_store.similarity_search(query)
[i.page_content for i in retireved_results]
# Out:
# ['Bus Provider: Hanif\nCoverage Districts: Dhaka, Khulna, Mymensingh, Comilla',
#  'Hanif Privacy Policy\n\nHanif is committed to protecting the privacy and personal data of our customers. We collect personal details such as names, phone numbers, travel history, and booking preferences to provide efficient booking and travel services. This information helps us improve service quality, offer relevant promotions, and ensure smooth operational management.\n\nOfficial Address: Gabtoli / Mirpur region, Dhaka Contact Information: Customer Support: 16460, Counter: 01713-049540 Privacy Policy / Terms Link: https://hanifenterprisebd.com/privacy-policy?utm_source=chatgpt.com\n\nAll collected information is stored securely, with access limited to authorized personnel only. Data sharing with external entities occurs strictly when required for legal or operational needs. Security protocols include encryption, access restrictions, and regular audits.',
#  'By utilizing Hanif services, you consent to the policies outlined here. Updates to this privacy policy will be posted on our website and are effective immediately upon publication.',
#  'District: Barishal\nDropping Point: Bakerganj\nPrice: 470']

# %%
retriever = vector_store.as_retriever()
retriever
# Out:
# VectorStoreRetriever(tags=['Chroma', 'GoogleGenerativeAIEmbeddings'], vectorstore=<langchain_chroma.vectorstores.Chroma object at 0x000001C2DDFB8550>, search_kwargs={})

# %%
from langchain.tools import tool

@tool(response_format="content_and_artifact")
def retrieve_context(query: str):
    """Retrieve information to help answer a query."""
    retrieved_docs = vector_store.similarity_search(query, k=2)
    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\nContent: {doc.page_content}")
        for doc in retrieved_docs
    )
    return serialized, retrieved_docs

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

tools = [retrieve_context]
# If desired, specify custom instructions
prompt = (
    "You have access to a tool that retrieves context from bus info database."
    "Use the tool to help answer user queries."
)
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
agent = create_agent(model, tools, system_prompt=prompt)

# %%
query = (
    "Show all bus providers operating from Chittagong to Sylhet."
)

for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Show all bus providers operating from Chittagong to Sylhet.
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (f4e3384a-708a-45e3-91c1-8a969035a4ed)
#  Call ID: f4e3384a-708a-45e3-91c1-8a969035a4ed
#   Args:
#     query: Bus providers operating from Chittagong to Sylhet
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'provider_name': 'Ena', 'type': 'bus provider', 'start_index': 0, 'coverage_districts': 'Chattogram, Sylhet, Barishal, Bogra'}
# Content: Bus Provider: Ena
# Coverage Districts: Chattogram, Sylhet, Barishal, Bogra
#
# Source: {'type': 'bus provider', 'start_index': 0, 'provider_name': 'Shyamoli', 'coverage_districts': 'Chattogram, Khulna, Sylhet, Bogra'}
# Content: Bus Provider: Shyamoli
# Coverage Districts: Chattogram, Khulna, Sylhet, Bogra
# ================================== Ai Message ==================================

# %%
from langchain.agents.middleware import dynamic_prompt, ModelRequest

@dynamic_prompt
def prompt_with_context(request: ModelRequest) -> str:
    """Inject context into state messages."""
    last_query = request.state["messages"][-1].text
    retrieved_docs = vector_store.similarity_search(last_query)

    docs_content = "\n\n".join(doc.page_content for doc in retrieved_docs)

    system_message = (
        "You are a helpful assistant. Use the following context in your response:"
        f"\n\n{docs_content}"
    )

    return system_message


agent = create_agent(model, tools=[], middleware=[prompt_with_context])

# %%
query = "WShow all bus providers operating from Chittagong to Sylhet."
for step in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# WShow all bus providers operating from Chittagong to Sylhet.
# ================================== Ai Message ==================================
#
# The following bus providers operate from Chittagong to Sylhet:
#
# *   **Ena**
# *   **Shyamoli**
# *   **Desh Travel**
